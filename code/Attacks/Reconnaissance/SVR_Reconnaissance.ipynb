# %% [markdown]
# ## **Mount implementation folder in google drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/FYP/Implementation/data
! ls
# Out:
# /content/drive/MyDrive/FYP/Implementation/data
# encoded-data.csv	preprosessing-dos.csv	  UNSW-NB15_1.csv
# NUSW-NB15_features.csv	selected_columns_all.csv  UNSW-NB15_2.csv
# OTset.csv		SVR-predict-data.csv	  UNSW-NB15_3.csv
# preprocessing.csv	testset.csv		  UNSW-NB15_4.csv

# %%
attack_type = 'Reconnaissance'

# %% [markdown]
# ## **Load balanced training datset for DOS attacks**
#
# Data = (x_train, y_train)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils import shuffle

#get select columns for training
select_col=pd.read_csv("selected_columns_all.csv", sep=',', on_bad_lines='skip', index_col=False)
columns=list(select_col[attack_type])

#create training dataset down sampling
df = pd.read_csv('encoded-data.csv', sep=',', on_bad_lines='skip', index_col=False)
attack_labels = ['Analysis', 'Backdoors', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'] + ['attack_cat','Label']


DoS_attacks = df[df[attack_type] == 1]
Normal_Data = df[df['Label'] == 0]
frames = [DoS_attacks, Normal_Data]
result = pd.concat(frames)
X=result.drop(labels=attack_labels, axis=1)
Y=result[[attack_type]]
X.head()

undersample = RandomUnderSampler(random_state=0)
# fit and apply the transform
X, Y = undersample.fit_resample(X,Y)


x_train,y_train  = shuffle(X[columns],Y)


X_train_DoS_normalized = preprocessing.normalize(x_train)
X_train_DoS_normalized
# Out:
# array([[1.74274690e-05, 1.86293634e-05, 3.00473603e-06, ...,
#         0.00000000e+00, 3.31121911e-04, 2.40378883e-06],
#        [3.90192495e-02, 3.93289261e-02, 7.74191459e-04, ...,
#         1.54838292e-04, 6.81288484e-03, 1.54838292e-04],
#        [0.00000000e+00, 1.82531170e-02, 4.31175992e-04, ...,
#         1.43725331e-04, 0.00000000e+00, 7.18626654e-05],
#        ...,
#        [0.00000000e+00, 3.02380952e-06, 7.14285714e-08, ...,
#         2.38095238e-08, 0.00000000e+00, 3.57142857e-08],
#        [5.59365314e-05, 5.97942233e-05, 3.85769182e-06, ...,
#         0.00000000e+00, 1.56236519e-04, 3.85769182e-06],
#        [0.00000000e+00, 2.26785714e-06, 5.35714286e-08, ...,
#         1.78571429e-08, 0.00000000e+00, 8.92857143e-09]])

# %% [markdown]
# ## **Create Test Set for DOS attacks**
#
# Data = (x_test_DOS_normalized, y_test)

# %%
import pandas as pd
import numpy as np
select_col=pd.read_csv("selected_columns_all.csv", sep=r'\s*,\s*', on_bad_lines='skip', index_col=False)

columns=list(select_col[attack_type])
test_data =pd.read_csv("testset.csv", sep=',', on_bad_lines='skip', index_col=False)
attack_labels = ['Analysis', 'Backdoors', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'] + ['attack_cat','Label']
attack_categories = ['Analysis', 'Backdoors', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Reconnaissance', 'Shellcode', 'Worms'] 

attacks = test_data[test_data['attack_cat'] == attack_type]
# print(DoS_attacks.shape)
Normal_Data = test_data[test_data['Label'] == 0]
# print(Normal_Data.shape)

frames = [attacks, Normal_Data]
result = pd.concat(frames)
X=result.drop(labels=['attack_cat', 'Label'], axis=1)
Y=result[['Label']]
X.head()

x_test,y_test  = shuffle(X[columns],Y)

x_test = x_test.replace('-','')
x_test = x_test.replace(r'^\s*$', np.nan, regex=True)

#delete raws with missing values
for i in x_test.columns.values.tolist():
  i = x_test.loc[x_test[i].isnull()].index
  x_test = x_test.drop(index=list(i))
  y_test = y_test.drop(index=list(i))

percent_missing = x_test.isnull().sum()
missing_value_df = pd.DataFrame({'column_name': x_test.columns, 'count_missing': percent_missing, 'To be dropped': (percent_missing > 45)})
print(missing_value_df)

x_test.head()
#encode the data
from sklearn.preprocessing import LabelEncoder

# replace hex with int
if 'sport' in x_test:
    x_test['sport'] = x_test['sport'].astype(str).apply(int, base=16)
if 'dsport' in x_test:
    x_test['dsport'] = x_test['dsport'].astype(str).apply(int, base=16)

# #Create an instance of Label-encoder
labelencoder = LabelEncoder() 

# # encode columns consists with strings
if 'srcip' in x_test:
    x_test['srcip'] = labelencoder.fit_transform(x_test['srcip'])
if 'dstip' in x_test:
    x_test['dstip'] = labelencoder.fit_transform(x_test['dstip'])
if 'proto' in x_test:
    x_test['proto'] = labelencoder.fit_transform(x_test['proto'])
if 'state' in x_test:
    x_test['state'] = labelencoder.fit_transform(x_test['state'])

X_test_DoS_normalized = preprocessing.normalize(x_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                        column_name  count_missing  To be dropped
# dttl                          dttl              0          False
# sttl                          sttl              0          False
# state                        state              0          False
# proto                        proto              0          False
# swin                          swin              0          False
# ct_dst_sport_ltm  ct_dst_sport_ltm              0          False
# srcip                        srcip              0          False
# dstip                        dstip              0          False
# smeansz                    smeansz              0          False
# sbytes                      sbytes              0          False
# Sload                        Sload              0          False
# ct_dst_ltm              ct_dst_ltm              0          False
# ct_state_ttl          ct_state_ttl              0          False
# dmeansz                    dmeansz              0          False
# ct_src_ ltm            ct_src_ ltm              0          False

# %% [markdown]
# **Normalization**

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd

# df=pd.read_csv('filtered-data.csv')
# X=df.drop(labels=['Label'], axis=1)
# # X=df.drop(labels=['attack_cat','Label'], axis=1)
# # Y=df[['attack_cat','Label']]
# Y=df[['Label']]

# # split the dataset
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train_DoS_normalized = preprocessing.normalize(x_train)
X_train_DoS_normalized 
# X_train_normalized = preprocessing.normalize(X_train)
# X_test_normalized = preprocessing.normalize(X_test)
# Out:
# array([[1.74274690e-05, 1.86293634e-05, 3.00473603e-06, ...,
#         0.00000000e+00, 3.31121911e-04, 2.40378883e-06],
#        [3.90192495e-02, 3.93289261e-02, 7.74191459e-04, ...,
#         1.54838292e-04, 6.81288484e-03, 1.54838292e-04],
#        [0.00000000e+00, 1.82531170e-02, 4.31175992e-04, ...,
#         1.43725331e-04, 0.00000000e+00, 7.18626654e-05],
#        ...,
#        [0.00000000e+00, 3.02380952e-06, 7.14285714e-08, ...,
#         2.38095238e-08, 0.00000000e+00, 3.57142857e-08],
#        [5.59365314e-05, 5.97942233e-05, 3.85769182e-06, ...,
#         0.00000000e+00, 1.56236519e-04, 3.85769182e-06],
#        [0.00000000e+00, 2.26785714e-06, 5.35714286e-08, ...,
#         1.78571429e-08, 0.00000000e+00, 8.92857143e-09]])

# %% [markdown]
# # **Support Vector Regression**

# %% [markdown]
# **Hyper Parameter Tuning - GridSearchCV**

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import classification_report
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
# 			'gamma': [1000, 100, 10, 1, 0.1, 0.01, 0.001, 0.0001],
# 			'kernel': ['rbf']}

# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)

# # fitting the model for grid search
# grid.fit(x, y.ravel())

# print(grid.best_params_)

# print(grid.best_estimator_)

# grid_predictions = grid.predict(x_test)

# print(classification_report(y_test, grid_predictions))

# %%
from sklearn.svm import SVR
import numpy as np

x = X_train_DoS_normalized
x_test=np.array(X_test_DoS_normalized)
y = np.array(y_train)
y_test = np.array(y_test)

# Fitting SVM regression to the Training set
SVM_regression = SVR(C=1000,gamma=100,kernel='rbf')
SVM_regression.fit(x, y.ravel())


# Predicting the Test set results
y_pred = SVM_regression.predict(x_test)

# predictions = pd.DataFrame({ 'y_test':y_test,'y_pred':y_pred})
# predictions.head()
print(x.shape)
print(x_test.shape)
# Out:
# (16966, 15)
# (446370, 15)

# %%
from sklearn.metrics import accuracy_score
bestThreshold = 0.00
bestAccuracy = 0.00
for i in range(1,100):
  y_predict_class = [1 if p > i/100 else 0 for p in y_pred]
  currentThreshold = i/100
  currentAccuracy = round(accuracy_score(y_test, y_predict_class), 6)
  print("Accuracy when threshold = ",currentThreshold, currentAccuracy)
  if currentAccuracy > bestAccuracy:
    bestAccuracy = currentAccuracy
    bestThreshold = currentThreshold
# Out:
# Accuracy when threshold =  0.01 0.200677
# Accuracy when threshold =  0.02 0.208323
# Accuracy when threshold =  0.03 0.215451
# Accuracy when threshold =  0.04 0.223115
# Accuracy when threshold =  0.05 0.239263
# Accuracy when threshold =  0.06 0.253341
# Accuracy when threshold =  0.07 0.26176
# Accuracy when threshold =  0.08 0.270563
# Accuracy when threshold =  0.09 0.279513
# Accuracy when threshold =  0.1 0.291162
# Accuracy when threshold =  0.11 0.304747
# Accuracy when threshold =  0.12 0.313328
# Accuracy when threshold =  0.13 0.320134
# Accuracy when threshold =  0.14 0.325129
# Accuracy when threshold =  0.15 0.330434
# Accuracy when threshold =  0.16 0.335867
# Accuracy when threshold =  0.17 0.341448
# Accuracy when threshold =  0.18 0.349468
# Accuracy when threshold =  0.19 0.358973
# Accuracy when threshold =  0.2 0.369189
# Accuracy when threshold =  0.21 0.377559
# Accuracy when threshold =  0.22 0.387436
# Accuracy when threshold =  0.23 0.397934
# Accuracy when threshold =  0.24 0.409662
# Accuracy when threshold =  0.25 0.421991
# Accuracy when threshold =  0.26 0.435258
# Accuracy when threshold =  0.27 0.449634
# Accuracy when threshold =  0.28 0.466837
# Accuracy when threshold =  0.29 0.487324
# Accuracy when threshold =  0.3 0.510615
# Accuracy when threshold =  0.31 0.533038
# Accuracy when threshold =  0.32 0.553776
# Accuracy when threshold =  0.33 0.569821
# Accuracy when threshold =  0.34 0.58456
# Accuracy when threshold =  0.35 0.596859
# Accuracy when threshold =  0.36 0.608267
# Accuracy when threshold =  0.37 0.617875
# Accuracy when threshold =  0.38 0.626863
# Accuracy when threshold =  0.39 0.632919
# Accuracy when threshold =  0.4 0.637852
# Accuracy when threshold =  0.41 0.642151
# Accuracy when threshold =  0.42 0.645814
# Accuracy when threshold =  0.43 0.649723
# Accuracy when threshold =  0.44 0.653388
# Accuracy when threshold =  0.45 0.657423
# Accuracy when threshold =  0.46 0.661162
# Accuracy when threshold =  0.47 0.665858
# Accuracy when threshold =  0.48 0.669619
# Accuracy when threshold =  0.49 0.674696
# Accuracy when threshold =  0.5 0.67925
# Accuracy when threshold =  0.51 0.688418
# Accuracy when threshold =  0.52 0.695777
# Accuracy when threshold =  0.53 0.703943
# Accuracy when threshold =  0.54 0.707928
# Accuracy when threshold =  0.55 0.713829
# Accuracy when threshold =  0.56 0.717331
# Accuracy when threshold =  0.57 0.722506
# Accuracy when threshold =  0.58 0.726093
# Accuracy when threshold =  0.59 0.730782
# Accuracy when threshold =  0.6 0.736483
# Accuracy when threshold =  0.61 0.740995
# Accuracy when threshold =  0.62 0.745292
# Accuracy when threshold =  0.63 0.749275
# Accuracy when threshold =  0.64 0.754058
# Accuracy when threshold =  0.65 0.75596
# Accuracy when threshold =  0.66 0.760916
# Accuracy when threshold =  0.67 0.768533
# Accuracy when threshold =  0.68 0.78206
# Accuracy when threshold =  0.69 0.790427
# Accuracy when threshold =  0.7 0.795459
# Accuracy when threshold =  0.71 0.799211
# Accuracy when threshold =  0.72 0.802744
# Accuracy when threshold =  0.73 0.807268
# Accuracy when threshold =  0.74 0.812797
# Accuracy when threshold =  0.75 0.818754
# Accuracy when threshold =  0.76 0.826469
# Accuracy when threshold =  0.77 0.835408
# Accuracy when threshold =  0.78 0.841114
# Accuracy when threshold =  0.79 0.846087
# Accuracy when threshold =  0.8 0.851231
# Accuracy when threshold =  0.81 0.862096
# Accuracy when threshold =  0.82 0.866057
# Accuracy when threshold =  0.83 0.867881
# Accuracy when threshold =  0.84 0.868499
# Accuracy when threshold =  0.85 0.869019
# Accuracy when threshold =  0.86 0.870287
# Accuracy when threshold =  0.87 0.874998
# Accuracy when threshold =  0.88 0.877929
# Accuracy when threshold =  0.89 0.945453
# Accuracy when threshold =  0.9 0.975921
# Accuracy when threshold =  0.91 0.976181
# Accuracy when threshold =  0.92 0.976441
# Accuracy when threshold =  0.93 0.976705
# Accuracy when threshold =  0.94 0.976963
# Accuracy when threshold =  0.95 0.977203
# Accuracy when threshold =  0.96 0.977418
# Accuracy when threshold =  0.97 0.977669
# Accuracy when threshold =  0.98 0.978076
# Accuracy when threshold =  0.99 0.978569

# %%
print("Best Accuracy happens when threshold = ",bestThreshold, bestAccuracy)
# Out:
# Best Accuracy happens when threshold =  0.99 0.978569

# %% [markdown]
# **Test Set Accuracy**

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

y_predict_class = [1 if p > bestThreshold else 0 for p in y_pred]
confusion_matrix = metrics.confusion_matrix(y_test, y_predict_class)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show() 


print("Accuracy when threshould = ",bestThreshold, round(accuracy_score(y_test, y_predict_class), 6))
# Out:
# Accuracy when threshould =  0.99 0.978569
